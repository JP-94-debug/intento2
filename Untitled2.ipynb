# %% [markdown]
# <a href="https://colab.research.google.com/github/JP-94-debug/intento2/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: create a script to plot the math problem of 3n+1

import matplotlib.pyplot as plt

def collatz(n):
  """Generates the Collatz sequence for a given number."""
  sequence = [n]
  while n != 1:
    if n % 2 == 0:
      n = n // 2
    else:
      n = 3 * n + 1
    sequence.append(n)
  return sequence

# Get input from the user
n = int(input("Enter a starting number: "))

# Generate the Collatz sequence
sequence = collatz(n)

# Plot the sequence
plt.plot(sequence)
plt.xlabel("Iteration")
plt.ylabel("Number")
plt.title("Collatz Conjecture for n = " + str(n))
plt.show()
# Out:
# Enter a starting number: 13
